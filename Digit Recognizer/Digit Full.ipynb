# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import *
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.csv')

y = train_data.label
X = train_data.drop('label', axis=1)
X = tf.constant(X).astype(tf.uint8).reshape(-1, 28, 28, 1)
X_test = tf.constant(test_data).astype(tf.uint8).reshape(-1, 28, 28, 1)

X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=0)

# %%
model = tf.keras.Sequential([
    BatchNormalization(input_shape=[28, 28, 1]),
    Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'),
    MaxPooling2D(pool_size=2, padding='same'),

    BatchNormalization(),
    Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    MaxPooling2D(pool_size=2, padding='same'),

    BatchNormalization(),
    Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    MaxPooling2D(pool_size=2, padding='same'),

    BatchNormalization(),
    Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
    MaxPooling2D(pool_size=2, padding='same'),

    BatchNormalization(),
    Conv2D(filters=512, kernel_size=3, activation='relu', padding='same'),
    MaxPooling2D(pool_size=2, padding='same'),

    Flatten(),
    Dense(20, activation='relu'),
    Dropout(rate=0.3),
    Dense(10),
])

model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy'],
)

fit_object = model.fit(
    X, y,
    epochs=100,
    batch_size=30000,
)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 59s 16s/step - loss: 2.6085 - accuracy: 0.1160
# Epoch 2/100
# 2/2 [==============================] - 2s 552ms/step - loss: 2.1209 - accuracy: 0.3034
# Epoch 3/100
# 2/2 [==============================] - 2s 551ms/step - loss: 1.7817 - accuracy: 0.3273
# Epoch 4/100
# 2/2 [==============================] - 2s 557ms/step - loss: 1.5109 - accuracy: 0.4136
# Epoch 5/100
# 2/2 [==============================] - 2s 559ms/step - loss: 1.2494 - accuracy: 0.5224
# Epoch 6/100
# 2/2 [==============================] - 2s 558ms/step - loss: 1.0476 - accuracy: 0.5988
# Epoch 7/100
# 2/2 [==============================] - 2s 563ms/step - loss: 0.9111 - accuracy: 0.6516
# Epoch 8/100
# 2/2 [==============================] - 2s 552ms/step - loss: 0.8165 - accuracy: 0.6835
# Epoch 9/100
# 2/2 [==============================] - 2s 559ms/step - loss: 0.7198 - accuracy: 0.7290
# Epoch 10/100
# 2/2 [==============================] - 2s 555ms/step - loss: 0.6392 - accuracy: 0.7708
# Epoch 11/100
# 2/2 [==============================] - 2s 559ms/step - loss: 0.5788 - accuracy: 0.7900
# Epoch 12/100
# 2/2 [==============================] - 2s 563ms/step - loss: 0.5310 - accuracy: 0.8043
# Epoch 13/100
# 2/2 [==============================] - 2s 562ms/step - loss: 0.4846 - accuracy: 0.8185
# Epoch 14/100
# 2/2 [==============================] - 2s 565ms/step - loss: 0.4447 - accuracy: 0.8366
# Epoch 15/100
# 2/2 [==============================] - 2s 563ms/step - loss: 0.4171 - accuracy: 0.8489
# Epoch 16/100
# 2/2 [==============================] - 2s 560ms/step - loss: 0.3841 - accuracy: 0.8629
# Epoch 17/100
# 2/2 [==============================] - 2s 559ms/step - loss: 0.3621 - accuracy: 0.8706
# Epoch 18/100
# 2/2 [==============================] - 2s 576ms/step - loss: 0.3407 - accuracy: 0.8815
# Epoch 19/100
# 2/2 [==============================] - 2s 573ms/step - loss: 0.3252 - accuracy: 0.8821
# Epoch 20/100
# 2/2 [==============================] - 2s 575ms/step - loss: 0.3040 - accuracy: 0.8878
# Epoch 21/100
# 2/2 [==============================] - 2s 571ms/step - loss: 0.2862 - accuracy: 0.8947
# Epoch 22/100
# 2/2 [==============================] - 2s 572ms/step - loss: 0.2738 - accuracy: 0.8984
# Epoch 23/100
# 2/2 [==============================] - 2s 579ms/step - loss: 0.2571 - accuracy: 0.9036
# Epoch 24/100
# 2/2 [==============================] - 2s 584ms/step - loss: 0.2483 - accuracy: 0.9076
# Epoch 25/100
# 2/2 [==============================] - 2s 577ms/step - loss: 0.2345 - accuracy: 0.9133
# Epoch 26/100
# 2/2 [==============================] - 2s 573ms/step - loss: 0.2213 - accuracy: 0.9161
# Epoch 27/100
# 2/2 [==============================] - 2s 578ms/step - loss: 0.2182 - accuracy: 0.9165
# Epoch 28/100
# 2/2 [==============================] - 2s 581ms/step - loss: 0.2052 - accuracy: 0.9227
# Epoch 29/100
# 2/2 [==============================] - 2s 571ms/step - loss: 0.2008 - accuracy: 0.9262
# Epoch 30/100
# 2/2 [==============================] - 2s 577ms/step - loss: 0.1877 - accuracy: 0.9321
# Epoch 31/100
# 2/2 [==============================] - 2s 583ms/step - loss: 0.1781 - accuracy: 0.9358
# Epoch 32/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.1766 - accuracy: 0.9370
# Epoch 33/100
# 2/2 [==============================] - 2s 577ms/step - loss: 0.1711 - accuracy: 0.9384
# Epoch 34/100
# 2/2 [==============================] - 2s 592ms/step - loss: 0.1610 - accuracy: 0.9432
# Epoch 35/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.1597 - accuracy: 0.9416
# Epoch 36/100
# 2/2 [==============================] - 2s 592ms/step - loss: 0.1512 - accuracy: 0.9440
# Epoch 37/100
# 2/2 [==============================] - 2s 592ms/step - loss: 0.1451 - accuracy: 0.9463
# Epoch 38/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.1422 - accuracy: 0.9469
# Epoch 39/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.1396 - accuracy: 0.9481
# Epoch 40/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.1340 - accuracy: 0.9509
# Epoch 41/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.1350 - accuracy: 0.9495
# Epoch 42/100
# 2/2 [==============================] - 2s 589ms/step - loss: 0.1297 - accuracy: 0.9516
# Epoch 43/100
# 2/2 [==============================] - 2s 598ms/step - loss: 0.1267 - accuracy: 0.9519
# Epoch 44/100
# 2/2 [==============================] - 2s 589ms/step - loss: 0.1238 - accuracy: 0.9533
# Epoch 45/100
# 2/2 [==============================] - 2s 597ms/step - loss: 0.1166 - accuracy: 0.9577
# Epoch 46/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.1151 - accuracy: 0.9580
# Epoch 47/100
# 2/2 [==============================] - 2s 586ms/step - loss: 0.1112 - accuracy: 0.9600
# Epoch 48/100
# 2/2 [==============================] - 2s 596ms/step - loss: 0.1123 - accuracy: 0.9600
# Epoch 49/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.1093 - accuracy: 0.9610
# Epoch 50/100
# 2/2 [==============================] - 2s 599ms/step - loss: 0.1082 - accuracy: 0.9615
# Epoch 51/100
# 2/2 [==============================] - 2s 596ms/step - loss: 0.1061 - accuracy: 0.9636
# Epoch 52/100
# 2/2 [==============================] - 2s 587ms/step - loss: 0.1029 - accuracy: 0.9639
# Epoch 53/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.1000 - accuracy: 0.9666
# Epoch 54/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0965 - accuracy: 0.9682
# Epoch 55/100
# 2/2 [==============================] - 2s 597ms/step - loss: 0.0959 - accuracy: 0.9680
# Epoch 56/100
# 2/2 [==============================] - 2s 596ms/step - loss: 0.0978 - accuracy: 0.9670
# Epoch 57/100
# 2/2 [==============================] - 2s 596ms/step - loss: 0.0948 - accuracy: 0.9682
# Epoch 58/100
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0934 - accuracy: 0.9680
# Epoch 59/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0885 - accuracy: 0.9697
# Epoch 60/100
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0854 - accuracy: 0.9712
# Epoch 61/100
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0877 - accuracy: 0.9693
# Epoch 62/100
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0835 - accuracy: 0.9716
# Epoch 63/100
# 2/2 [==============================] - 2s 597ms/step - loss: 0.0845 - accuracy: 0.9706
# Epoch 64/100
# 2/2 [==============================] - 2s 599ms/step - loss: 0.0838 - accuracy: 0.9708
# Epoch 65/100
# 2/2 [==============================] - 2s 586ms/step - loss: 0.0828 - accuracy: 0.9710
# Epoch 66/100
# 2/2 [==============================] - 2s 581ms/step - loss: 0.0792 - accuracy: 0.9719
# Epoch 67/100
# 2/2 [==============================] - 2s 586ms/step - loss: 0.0798 - accuracy: 0.9717
# Epoch 68/100
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0788 - accuracy: 0.9715
# Epoch 69/100
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0797 - accuracy: 0.9716
# Epoch 70/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0756 - accuracy: 0.9723
# Epoch 71/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.0763 - accuracy: 0.9717
# Epoch 72/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0750 - accuracy: 0.9721
# Epoch 73/100
# 2/2 [==============================] - 2s 586ms/step - loss: 0.0735 - accuracy: 0.9730
# Epoch 74/100
# 2/2 [==============================] - 2s 596ms/step - loss: 0.0718 - accuracy: 0.9724
# Epoch 75/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.0717 - accuracy: 0.9725
# Epoch 76/100
# 2/2 [==============================] - 2s 587ms/step - loss: 0.0682 - accuracy: 0.9745
# Epoch 77/100
# 2/2 [==============================] - 2s 597ms/step - loss: 0.0706 - accuracy: 0.9731
# Epoch 78/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0692 - accuracy: 0.9741
# Epoch 79/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0714 - accuracy: 0.9721
# Epoch 80/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0701 - accuracy: 0.9732
# Epoch 81/100
# 2/2 [==============================] - 2s 588ms/step - loss: 0.0688 - accuracy: 0.9735
# Epoch 82/100
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0667 - accuracy: 0.9737
# Epoch 83/100
# 2/2 [==============================] - 2s 604ms/step - loss: 0.0659 - accuracy: 0.9745
# Epoch 84/100
# 2/2 [==============================] - 2s 596ms/step - loss: 0.0650 - accuracy: 0.9750
# Epoch 85/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.0633 - accuracy: 0.9753
# Epoch 86/100
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0632 - accuracy: 0.9755
# Epoch 87/100
# 2/2 [==============================] - 2s 591ms/step - loss: 0.0644 - accuracy: 0.9742
# Epoch 88/100
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0623 - accuracy: 0.9755
# Epoch 89/100
# 2/2 [==============================] - 2s 597ms/step - loss: 0.0623 - accuracy: 0.9755
# Epoch 90/100
# 2/2 [==============================] - 2s 598ms/step - loss: 0.0618 - accuracy: 0.9751
# Epoch 91/100
# 2/2 [==============================] - 2s 589ms/step - loss: 0.0627 - accuracy: 0.9746
# Epoch 92/100
# 2/2 [==============================] - 2s 593ms/step - loss: 0.0607 - accuracy: 0.9755
# Epoch 93/100
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0596 - accuracy: 0.9758
# Epoch 94/100
# 2/2 [==============================] - 2s 599ms/step - loss: 0.0596 - accuracy: 0.9760
# Epoch 95/100
# 2/2 [==============================] - 2s 589ms/step - loss: 0.0613 - accuracy: 0.9753
# Epoch 96/100
# 2/2 [==============================] - 2s 594ms/step - loss: 0.0559 - accuracy: 0.9770
# Epoch 97/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0574 - accuracy: 0.9769
# Epoch 98/100
# 2/2 [==============================] - 2s 590ms/step - loss: 0.0567 - accuracy: 0.9765
# Epoch 99/100
# 2/2 [==============================] - 2s 595ms/step - loss: 0.0577 - accuracy: 0.9757
# Epoch 100/100
# 2/2 [==============================] - 2s 592ms/step - loss: 0.0578 - accuracy: 0.9760

# %%
yhat_test = np.argmax(model.predict(X_test), axis=1)

output_df = pd.DataFrame({
    'ImageId': range(1, len(test_data)+1),
    'Label': yhat_test,
})

output_df.to_csv('/content/drive/MyDrive/Colab Notebooks/submission_3.csv', index=False)
# Out:
# 875/875 [==============================] - 2s 2ms/step
